# %%
# package
import pandas as pd
import numpy as np
import yfinance  as yf
import matplotlib.pyplot as plt
from scipy.optimize import minimize, rosen, rosen_der

# constant
figsize = (12, 8) 
rf = 0.015
num_portfolios = 1000000
n_cut = 50   # num of cut from linspace
A = 4 # Aversion

# %%
symbols_list_good = ["APAM", "TMV", "PSK", "WPM", "TPL"]
symbols_list_poor = ["CIA", "CLF", "ATI", "EVR", "CRS"]
count_good = len(symbols_list_good)
count_poor = len(symbols_list_poor)
symbols_good = []
symbols_poor = []

for ticker in symbols_list_good:
    tick = yf.Ticker(ticker)
    history = tick.history(period='max')
    history['Symbol'] = ticker
    symbols_good.append(history)
    
for ticker in symbols_list_poor:
    tick = yf.Ticker(ticker)
    history = tick.history(period='max')
    history['Symbol'] = ticker
    symbols_poor.append(history)

df = pd.concat(symbols_good)
df = df.reset_index()
df = df[['Date', 'Close', 'Symbol']]
df = df.drop_duplicates()
price_good = df.pivot('Date','Symbol','Close').reset_index()
price_good.index = price_good.Date
price_good.drop(columns=['Date'], inplace=True)  

df = pd.concat(symbols_poor)
df = df.reset_index()
df = df[['Date', 'Close', 'Symbol']]
df = df.drop_duplicates()
price_poor = df.pivot('Date','Symbol','Close').reset_index()
price_poor.index = price_poor.Date
price_poor.drop(columns=['Date'], inplace=True)

# %%
price_good
# Out:
# Symbol                          APAM        PSK         TMV          TPL  \
# Date
# 1980-03-17 00:00:00-05:00        NaN        NaN         NaN     4.629041
# 1980-03-18 00:00:00-05:00        NaN        NaN         NaN     4.397588
# 1980-03-19 00:00:00-05:00        NaN        NaN         NaN     4.496782
# 1980-03-20 00:00:00-05:00        NaN        NaN         NaN     4.513315
# 1980-03-21 00:00:00-05:00        NaN        NaN         NaN     4.529847
# ...                              ...        ...         ...          ...
# 2023-05-01 00:00:00-04:00  34.560001  33.990002  115.629997  1477.140015
# 2023-05-02 00:00:00-04:00  33.400002  33.410000  107.300003  1435.979980
# 2023-05-03 00:00:00-04:00  32.939999  32.849998  105.529999  1433.150024
# 2023-05-04 00:00:00-04:00  31.790001  31.879999  108.730003  1381.199951
# 2023-05-05 00:00:00-04:00  32.880001  32.419998  110.500000  1398.000000
#
# Symbol                           WPM
# Date
# 1980-03-17 00:00:00-05:00        NaN
# 1980-03-18 00:00:00-05:00        NaN
# 1980-03-19 00:00:00-05:00        NaN
# 1980-03-20 00:00:00-05:00        NaN
# 1980-03-21 00:00:00-05:00        NaN
# ...                              ...
# 2023-05-01 00:00:00-04:00  48.900002
# 2023-05-02 00:00:00-04:00  51.000000
# 2023-05-03 00:00:00-04:00  50.669998
# 2023-05-04 00:00:00-04:00  51.410000
# 2023-05-05 00:00:00-04:00  52.430000
#
# [10877 rows x 5 columns]

# %%
price_poor
# Out:
# Symbol                           ATI   CIA        CLF        CRS         EVR
# Date
# 1973-02-21 00:00:00-05:00        NaN   NaN   0.836691   1.005395         NaN
# 1973-02-22 00:00:00-05:00        NaN   NaN   0.839935   1.010830         NaN
# 1973-02-23 00:00:00-05:00        NaN   NaN   0.836406   1.032568         NaN
# 1973-02-26 00:00:00-05:00        NaN   NaN   0.823337   1.005395         NaN
# 1973-02-27 00:00:00-05:00        NaN   NaN   0.820070   1.005395         NaN
# ...                              ...   ...        ...        ...         ...
# 2023-05-01 00:00:00-04:00  37.919998  1.91  15.210000  51.599998  111.470001
# 2023-05-02 00:00:00-04:00  38.310001  1.87  15.280000  54.340000  108.699997
# 2023-05-03 00:00:00-04:00  38.000000  1.76  15.010000  52.130001  107.750000
# 2023-05-04 00:00:00-04:00  35.360001  1.78  14.260000  49.720001  106.839996
# 2023-05-05 00:00:00-04:00  36.740002  1.74  15.085000  49.959999  108.724998
#
# [12663 rows x 5 columns]

# %% [markdown]
# # Monthly Price

# %%
month_price_good = price_good.resample("1 m").agg("last")
month_price_poor = price_poor.resample("1 m").agg("last")

# %%
month_price_good
# Out:
# Symbol                          APAM        PSK         TMV          TPL  \
# Date
# 1980-03-31 00:00:00-05:00        NaN        NaN         NaN     3.967749
# 1980-04-30 00:00:00-04:00        NaN        NaN         NaN     4.629041
# 1980-05-31 00:00:00-04:00        NaN        NaN         NaN     4.959685
# 1980-06-30 00:00:00-04:00        NaN        NaN         NaN     4.926622
# 1980-07-31 00:00:00-04:00        NaN        NaN         NaN     5.918559
# ...                              ...        ...         ...          ...
# 2023-01-31 00:00:00-05:00  35.899502  35.885246  107.183395  1992.289917
# 2023-02-28 00:00:00-05:00  32.970001  34.925438  124.760437  1777.014526
# 2023-03-31 00:00:00-04:00  31.980000  33.427307  107.209999  1701.020020
# 2023-04-30 00:00:00-04:00  34.669998  34.119999  106.459999  1477.650024
# 2023-05-31 00:00:00-04:00  32.880001  32.419998  110.500000  1398.000000
#
# Symbol                           WPM
# Date
# 1980-03-31 00:00:00-05:00        NaN
# 1980-04-30 00:00:00-04:00        NaN
# 1980-05-31 00:00:00-04:00        NaN
# 1980-06-30 00:00:00-04:00        NaN
# 1980-07-31 00:00:00-04:00        NaN
# ...                              ...
# 2023-01-31 00:00:00-05:00  45.590588
# 2023-02-28 00:00:00-05:00  41.513950
# 2023-03-31 00:00:00-04:00  48.160000
# 2023-04-30 00:00:00-04:00  49.380001
# 2023-05-31 00:00:00-04:00  52.430000
#
# [519 rows x 5 columns]

# %%
month_price_poor
# Out:
# Symbol                           ATI   CIA        CLF        CRS         EVR
# Date
# 1973-02-28 00:00:00-05:00        NaN   NaN   0.816803   1.016264         NaN
# 1973-03-31 00:00:00-05:00        NaN   NaN   0.757993   1.010830         NaN
# 1973-04-30 00:00:00-04:00        NaN   NaN   0.807001   1.021699         NaN
# 1973-05-31 00:00:00-04:00        NaN   NaN   0.774329   0.907573         NaN
# 1973-06-30 00:00:00-04:00        NaN   NaN   0.803734   0.902139         NaN
# ...                              ...   ...        ...        ...         ...
# 2023-01-31 00:00:00-05:00  36.389999  2.40  21.350000  48.106876  129.068817
# 2023-02-28 00:00:00-05:00  40.650002  2.95  21.330000  48.146725  131.179993
# 2023-03-31 00:00:00-04:00  39.459999  3.71  18.330000  44.590260  115.379997
# 2023-04-30 00:00:00-04:00  38.619999  1.87  15.380000  52.540001  114.070000
# 2023-05-31 00:00:00-04:00  36.740002  1.74  15.085000  49.959999  108.724998
#
# [604 rows x 5 columns]

# %%
month_ret_good = month_price_good.pct_change()
month_ret_good = month_ret_good.iloc[-61:-1]
month_ret_good
# Out:
# Symbol                         APAM       PSK       TMV       TPL       WPM
# Date
# 2018-05-31 00:00:00-04:00  0.023415  0.011268 -0.059903  0.296983  0.055784
# 2018-06-30 00:00:00-04:00 -0.066564  0.013759 -0.019744 -0.016060  0.009149
# 2018-07-31 00:00:00-04:00  0.142621 -0.002543  0.045621  0.064327 -0.050317
# 2018-08-31 00:00:00-04:00 -0.019693  0.013734 -0.036610  0.127729 -0.175863
# 2018-09-30 00:00:00-04:00 -0.022624 -0.016609  0.091691  0.033489  0.018626
# 2018-10-31 00:00:00-04:00 -0.154013 -0.020032  0.092256 -0.118763 -0.061143
# 2018-11-30 00:00:00-05:00  0.016420 -0.025133 -0.049891 -0.238028 -0.042626
# 2018-12-31 00:00:00-05:00 -0.188028 -0.005391 -0.157856 -0.064849  0.248721
# 2019-01-31 00:00:00-05:00  0.054726  0.060919 -0.007680  0.283921  0.079365
# 2019-02-28 00:00:00-05:00  0.203737  0.012689  0.043671  0.069326  0.032258
# 2019-03-31 00:00:00-04:00 -0.042966  0.013777 -0.149988  0.049050  0.094669
# 2019-04-30 00:00:00-04:00  0.125944  0.007297  0.064959  0.037084 -0.086337
# 2019-05-31 00:00:00-04:00 -0.146983  0.007748 -0.178299 -0.081424  0.024028
# 2019-06-30 00:00:00-04:00  0.163637  0.011471 -0.027167  0.067814  0.094118
# 2019-07-31 00:00:00-04:00  0.075218  0.021622 -0.005900  0.012974  0.080232
# 2019-08-31 00:00:00-04:00 -0.078612  0.008917 -0.279674 -0.178111  0.129703
# 2019-09-30 00:00:00-04:00  0.060060  0.005235  0.075544 -0.008608 -0.107786
# 2019-10-31 00:00:00-04:00 -0.031516  0.004777  0.029836 -0.123990  0.069741
# 2019-11-30 00:00:00-05:00  0.109542 -0.010002  0.012150  0.186194 -0.015319
# 2019-12-31 00:00:00-05:00  0.089316  0.020189  0.093399  0.157397  0.079817
# 2020-01-31 00:00:00-05:00  0.033416  0.009544 -0.198816 -0.032654 -0.010084
# 2020-02-29 00:00:00-05:00 -0.114556 -0.033228 -0.183738 -0.079276 -0.032258
# 2020-03-31 00:00:00-04:00 -0.248076 -0.079615 -0.307891 -0.440194 -0.030560
# 2020-04-30 00:00:00-04:00  0.369940  0.076903 -0.049719  0.499039  0.371594
# 2020-05-31 00:00:00-04:00  0.006729  0.017047  0.044225  0.029386  0.141242
# 2020-06-30 00:00:00-04:00  0.121850 -0.007824 -0.023823  0.014154  0.024418
# 2020-07-31 00:00:00-04:00  0.114769  0.041997 -0.127252 -0.103751  0.233371
# 2020-08-31 00:00:00-04:00  0.087315  0.013414  0.159343 -0.011764 -0.015754
# 2020-09-30 00:00:00-04:00  0.007233 -0.003895 -0.030245 -0.142694 -0.080570
# 2020-10-31 00:00:00-04:00  0.027443 -0.002310  0.100276 -0.002547 -0.060322
# 2020-11-30 00:00:00-05:00  0.144823  0.023715 -0.063330  0.354144 -0.148581
# 2020-12-31 00:00:00-05:00  0.118667  0.018670  0.034476  0.209674  0.066429
# 2021-01-31 00:00:00-05:00 -0.038538 -0.022743  0.108313  0.144759 -0.016052
# 2021-02-28 00:00:00-05:00  0.005516 -0.017816  0.172068  0.326588 -0.129778
# 2021-03-31 00:00:00-04:00  0.098316  0.027442  0.161203  0.443026  0.072786
# 2021-04-30 00:00:00-04:00 -0.023960  0.007168 -0.075488 -0.031005  0.081392
# 2021-05-31 00:00:00-04:00  0.020783  0.005071 -0.004912 -0.056507  0.165619
# 2021-06-30 00:00:00-04:00 -0.005090  0.018425 -0.130620  0.102941 -0.082257
# 2021-07-31 00:00:00-04:00 -0.053719 -0.002952 -0.117250 -0.067005  0.047198
# 2021-08-31 00:00:00-04:00  0.101573 -0.001830  0.001391 -0.088982 -0.020687
# 2021-09-30 00:00:00-04:00 -0.058507 -0.000230  0.081597 -0.108703 -0.165631
# 2021-10-31 00:00:00-04:00  0.012674  0.002080 -0.080257  0.053177  0.075306
# 2021-11-30 00:00:00-05:00 -0.077783 -0.021301 -0.096510 -0.050955  0.037164
# 2021-12-31 00:00:00-05:00  0.065057  0.023804  0.051961  0.035428  0.027771
# 2022-01-31 00:00:00-05:00 -0.092989 -0.039385  0.108336 -0.139222 -0.060797
# 2022-02-28 00:00:00-05:00 -0.079576 -0.037768  0.037276  0.105795  0.086062
# 2022-03-31 00:00:00-04:00  0.032537 -0.007632  0.146941  0.140073  0.089948
# 2022-04-30 00:00:00-04:00 -0.183227 -0.069534  0.328366  0.010717 -0.057167
# 2022-05-31 00:00:00-04:00  0.221395  0.039221  0.045078  0.145902 -0.075608
# 2022-06-30 00:00:00-04:00 -0.073939 -0.035772  0.017755 -0.036614 -0.127814
# 2022-07-31 00:00:00-04:00  0.117796  0.059434 -0.080130  0.232409 -0.048016
# 2022-08-31 00:00:00-04:00 -0.137534 -0.047062  0.132969  0.003605 -0.106704
# 2022-09-30 00:00:00-04:00 -0.202310 -0.022434  0.263949 -0.032795  0.060984
# 2022-10-31 00:00:00-04:00  0.058671 -0.056517  0.196858  0.296326  0.010198
# 2022-11-30 00:00:00-05:00  0.237420  0.060848 -0.200050  0.125298  0.198869
# 2022-12-31 00:00:00-05:00 -0.143845 -0.039512  0.064786 -0.094680  0.001281
# 2023-01-31 00:00:00-05:00  0.239731  0.121877 -0.204697 -0.148612  0.170420
# 2023-02-28 00:00:00-05:00 -0.081603 -0.026747  0.163990 -0.108054 -0.089418
# 2023-03-31 00:00:00-04:00 -0.030027 -0.042895 -0.140673 -0.042765  0.160092
# 2023-04-30 00:00:00-04:00  0.084115  0.020722 -0.006996 -0.131315  0.025332

# %%
month_ret_poor = month_price_poor.pct_change()
month_ret_poor = month_ret_poor.iloc[-61:-1]
month_ret_poor
# Out:
# Symbol                          ATI       CIA       CLF       CRS       EVR
# Date
# 2018-05-31 00:00:00-04:00  0.073391 -0.046332  0.140162  0.125423  0.035822
# 2018-06-30 00:00:00-04:00 -0.119215  0.051282 -0.003546 -0.122956  0.010057
# 2018-07-31 00:00:00-04:00  0.106688  0.015404  0.279953  0.041849  0.071598
# 2018-08-31 00:00:00-04:00 -0.027698  0.061947 -0.068582  0.093212 -0.056172
# 2018-09-30 00:00:00-04:00  0.093230  0.000000  0.259701 -0.012066 -0.052755
# 2018-10-31 00:00:00-04:00 -0.123858 -0.064286 -0.150079 -0.257402 -0.187569
# 2018-11-30 00:00:00-05:00  0.014291  0.005089 -0.137547 -0.012153  0.016698
# 2018-12-31 00:00:00-05:00 -0.170982 -0.048101 -0.171336 -0.173398 -0.133236
# 2019-01-31 00:00:00-05:00  0.258153 -0.057181  0.401634  0.327155  0.250000
# 2019-02-28 00:00:00-05:00  0.045272 -0.036671  0.035481 -0.002594  0.035227
# 2019-03-31 00:00:00-04:00 -0.106881 -0.023426 -0.099188 -0.023221 -0.011944
# 2019-04-30 00:00:00-04:00 -0.025420  0.013493  0.004762  0.087673  0.070660
# 2019-05-31 00:00:00-04:00 -0.140851 -0.051775 -0.129129 -0.183411 -0.201562
# 2019-06-30 00:00:00-04:00  0.177020  0.138846  0.226437  0.182939  0.146834
# 2019-07-31 00:00:00-04:00 -0.136111  0.020548  0.004572 -0.061901 -0.024839
# 2019-08-31 00:00:00-04:00 -0.089573 -0.157047 -0.255159  0.085465 -0.069518
# 2019-09-30 00:00:00-04:00  0.021695  0.093949 -0.090680  0.062089  0.004263
# 2019-10-31 00:00:00-04:00  0.037531 -0.030568  0.016331 -0.047407 -0.080649
# 2019-11-30 00:00:00-05:00  0.097573  0.024024  0.105118  0.072420  0.058540
# 2019-12-31 00:00:00-05:00 -0.104076 -0.010264  0.051314 -0.053072 -0.033859
# 2020-01-31 00:00:00-05:00 -0.165053 -0.102222 -0.158273 -0.197894  0.024880
# 2020-02-29 00:00:00-05:00 -0.009275 -0.036304 -0.172365 -0.075239 -0.123333
# 2020-03-31 00:00:00-04:00 -0.502633  0.116438 -0.320138 -0.469388 -0.308616
# 2020-04-30 00:00:00-04:00 -0.116471 -0.147239  0.126650  0.136923  0.120278
# 2020-05-31 00:00:00-04:00  0.155792  0.093525  0.191781  0.064062  0.078462
# 2020-06-30 00:00:00-04:00  0.173963 -0.014803  0.057471  0.038939  0.069134
# 2020-07-31 00:00:00-04:00 -0.147203 -0.041736 -0.061594 -0.079077 -0.061439
# 2020-08-31 00:00:00-04:00 -0.041427  0.019164  0.270270 -0.050260  0.129294
# 2020-09-30 00:00:00-04:00  0.046819 -0.052991 -0.024316 -0.136472  0.057854
# 2020-10-31 00:00:00-04:00  0.056193  0.041516  0.289720 -0.026942  0.215093
# 2020-11-30 00:00:00-05:00  0.464712  0.098787  0.329710  0.398169  0.150714
# 2020-12-31 00:00:00-05:00  0.243143 -0.096215  0.322434  0.191489  0.205763
# 2021-01-31 00:00:00-05:00  0.014311  0.055846  0.053571  0.072802 -0.004925
# 2021-02-28 00:00:00-05:00  0.155791  0.003306 -0.130378  0.309923  0.103220
# 2021-03-31 00:00:00-04:00  0.071211 -0.046129  0.507496  0.012051  0.099942
# 2021-04-30 00:00:00-04:00  0.104463  0.008636 -0.111885 -0.079708  0.063686
# 2021-05-31 00:00:00-04:00  0.052880 -0.106164  0.126540  0.272100  0.045730
# 2021-06-30 00:00:00-04:00 -0.148632  0.013410  0.071571 -0.160684 -0.034896
# 2021-07-31 00:00:00-04:00 -0.015348  0.013233  0.159555 -0.051467 -0.060879
# 2021-08-31 00:00:00-04:00 -0.130054  0.113806 -0.061200 -0.120675  0.061493
# 2021-09-30 00:00:00-04:00 -0.068869  0.040201 -0.155944 -0.018291 -0.042753
# 2021-10-31 00:00:00-04:00 -0.031870  0.037037  0.217062 -0.050885  0.135932
# 2021-11-30 00:00:00-05:00 -0.115528 -0.119565 -0.155952 -0.110104 -0.082375
# 2021-12-31 00:00:00-05:00  0.118680 -0.063492  0.069779  0.062227 -0.020548
# 2022-01-31 00:00:00-05:00  0.148148 -0.105461 -0.212678 -0.009216 -0.081192
# 2022-02-28 00:00:00-05:00  0.407326 -0.105263  0.304551  0.336699  0.023215
# 2022-03-31 00:00:00-04:00  0.042735 -0.002353  0.440519  0.093514 -0.123534
# 2022-04-30 00:00:00-04:00  0.012668 -0.294811 -0.208631 -0.090519 -0.050036
# 2022-05-31 00:00:00-04:00  0.011773  0.110368 -0.090624 -0.072406  0.087043
# 2022-06-30 00:00:00-04:00 -0.174182  0.262048 -0.336928 -0.207777 -0.180298
# 2022-07-31 00:00:00-04:00  0.095993 -0.076372  0.152245  0.151558  0.067942
# 2022-08-31 00:00:00-04:00  0.202491 -0.020672 -0.024845  0.062507 -0.055932
# 2022-09-30 00:00:00-04:00 -0.110925 -0.118734 -0.220035 -0.083309 -0.122105
# 2022-10-31 00:00:00-04:00  0.118377 -0.194611 -0.035635  0.207683  0.277812
# 2022-11-30 00:00:00-05:00  0.025202  0.018587  0.191686  0.097861  0.103001
# 2022-12-31 00:00:00-05:00 -0.021304 -0.222628  0.040698 -0.100341 -0.052961
# 2023-01-31 00:00:00-05:00  0.218687  0.126761  0.325264  0.312597  0.190044
# 2023-02-28 00:00:00-05:00  0.117065  0.229167 -0.000937  0.000828  0.016357
# 2023-03-31 00:00:00-04:00 -0.029274  0.257627 -0.140647 -0.073867 -0.120445
# 2023-04-30 00:00:00-04:00 -0.021287 -0.495957 -0.160938  0.178284 -0.011354

# %% [markdown]
# # Mean and Std

# %%
mean_good = month_ret_good.mean() * 12
mean_poor = month_ret_poor.mean() * 12
print(mean_good, mean_poor)
# Out:
# Symbol
# APAM    0.199225
# PSK     0.020415
# TMV    -0.024964
# TPL     0.375760
# WPM     0.253247
# dtype: float64 Symbol
# ATI    0.217853
# CIA   -0.181066
# CLF    0.376969
# CRS    0.172867
# EVR    0.127372
# dtype: float64

# %%
std_good = month_ret_good.std() * np.sqrt(12)
std_poor = month_ret_poor.std() * np.sqrt(12)
print(std_good, std_poor)
# Out:
# Symbol
# APAM    0.420635
# PSK     0.119353
# TMV     0.445649
# TPL     0.578978
# WPM     0.370604
# dtype: float64 Symbol
# ATI    0.528737
# CIA    0.422195
# CLF    0.683722
# CRS    0.552376
# EVR    0.395849
# dtype: float64

# %% [markdown]
# # Distribution Chart - Good ESG Performance

# %%
month_ret_good.columns
# Out:
# Index(['APAM', 'PSK', 'TMV', 'TPL', 'WPM'], dtype='object', name='Symbol')

# %%
for symbol in month_ret_good.columns:
    month_ret_good[symbol].plot.hist()
    plt.title(symbol)
    plt.show()

# %% [markdown]
# # Distribution Chart - Poor ESG Performance

# %%
for symbol in month_ret_poor.columns:
    month_ret_poor[symbol].plot.hist()
    plt.title(symbol)
    plt.show()

# %% [markdown]
# # Covariance

# %%
cov_good = month_ret_good.cov()

# Alternative
# cov_good_matrix = month_ret_good.apply(lambda x: np.log(1+x)).cov()

cov_good
# Out:
# Symbol      APAM       PSK       TMV       TPL       WPM
# Symbol
# APAM    0.014744  0.003037 -0.000855  0.010675  0.003533
# PSK     0.003037  0.001187 -0.001353  0.002021  0.001495
# TMV    -0.000855 -0.001353  0.016550  0.006364 -0.004634
# TPL     0.010675  0.002021  0.006364  0.027935  0.001989
# WPM     0.003533  0.001495 -0.004634  0.001989  0.011446

# %%
cov_poor = month_ret_poor.cov()
cov_poor
# Out:
# Symbol       ATI       CIA       CLF       CRS       EVR
# Symbol
# ATI     0.023297 -0.000251  0.017828  0.019654  0.010675
# CIA    -0.000251  0.014854  0.002120 -0.002786 -0.000269
# CLF     0.017828  0.002120  0.038956  0.017465  0.013899
# CRS     0.019654 -0.002786  0.017465  0.025427  0.012053
# EVR     0.010675 -0.000269  0.013899  0.012053  0.013058

# %% [markdown]
# # Assets

# %%
assets_good = pd.concat([mean_good, std_good], axis=1)
assets_good.columns = ['Returns', 'Volatility']
assets_good
# Out:
#          Returns  Volatility
# Symbol
# APAM    0.199225    0.420635
# PSK     0.020415    0.119353
# TMV    -0.024964    0.445649
# TPL     0.375760    0.578978
# WPM     0.253247    0.370604

# %%
assets_poor = pd.concat([mean_poor, std_poor], axis=1)
assets_poor.columns = ['Returns', 'Volatility']
assets_poor
# Out:
#          Returns  Volatility
# Symbol
# ATI     0.217853    0.528737
# CIA    -0.181066    0.422195
# CLF     0.376969    0.683722
# CRS     0.172867    0.552376
# EVR     0.127372    0.395849

# %%
p_ret_good = []
p_vol_good = []
p_weights_good = []

p_ret_poor = []
p_vol_poor = []
p_weights_poor = []

num_assets_good = len(price_good.columns)
num_assets_poor = len(price_poor.columns)

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets_good)
    weights = weights/np.sum(weights)
    p_weights_good.append(weights)
    returns = np.dot(weights, mean_good)
    p_ret_good.append(returns)
    var = np.dot(weights.T, np.dot(cov_good, weights))
    sd = np.sqrt(var)
    ann_sd = sd*np.sqrt(12)
    p_vol_good.append(ann_sd)

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets_poor)
    weights = weights/np.sum(weights)
    p_weights_poor.append(weights)
    returns = np.dot(weights, mean_poor)
    p_ret_poor.append(returns)
    var = np.dot(weights.T, np.dot(cov_poor, weights))
    sd = np.sqrt(var)
    ann_sd = sd*np.sqrt(12)
    p_vol_poor.append(ann_sd)

# %%
data_good = {'Returns':p_ret_good, 'Volatility':p_vol_good}
pd.DataFrame( data_good )
# Out:
#          Returns  Volatility
# 0       0.190641    0.231088
# 1       0.203635    0.258353
# 2       0.157361    0.246556
# 3       0.157454    0.235794
# 4       0.155961    0.326472
# ...          ...         ...
# 999995  0.187680    0.344619
# 999996  0.167759    0.310777
# 999997  0.068065    0.226711
# 999998  0.144963    0.220589
# 999999  0.150452    0.225504
#
# [1000000 rows x 2 columns]

# %%
data_poor = {'Returns':p_ret_poor, 'Volatility':p_vol_poor}
pd.DataFrame( data_poor )
# Out:
#          Returns  Volatility
# 0       0.151022    0.384611
# 1       0.122519    0.371127
# 2       0.076486    0.327081
# 3       0.150346    0.395074
# 4       0.187257    0.420926
# ...          ...         ...
# 999995  0.131172    0.376403
# 999996  0.098855    0.354997
# 999997  0.148172    0.402025
# 999998  0.187460    0.419081
# 999999  0.118815    0.387273
#
# [1000000 rows x 2 columns]

# %%
for counter, symbol in enumerate(price_good.columns.tolist()):
    data_good[symbol+' weight'] = [w[counter] for w in p_weights_good]
    
for counter, symbol in enumerate(price_poor.columns.tolist()):
    data_poor[symbol+' weight'] = [w[counter] for w in p_weights_poor]

# %%
portfolios_good = pd.DataFrame(data_good)
portfolios_good['Sharpe Ratio'] = (portfolios_good['Returns']-rf) / portfolios_good['Volatility']
portfolios_good.head()
# Out:
#     Returns  Volatility  APAM weight  PSK weight  TMV weight  TPL weight  \
# 0  0.190641    0.231088     0.099981    0.262329    0.054321    0.154971
# 1  0.203635    0.258353     0.218996    0.270487    0.001160    0.208299
# 2  0.157361    0.246556     0.319610    0.306288    0.101313    0.170430
# 3  0.157454    0.235794     0.287611    0.180314    0.201365    0.144877
# 4  0.155961    0.326472     0.032269    0.111193    0.413659    0.370820
#
#    WPM weight  Sharpe Ratio
# 0    0.428399      0.760058
# 1    0.301058      0.730144
# 2    0.102360      0.577397
# 3    0.185833      0.604148
# 4    0.072059      0.431770

# %%
portfolios_poor = pd.DataFrame(data_poor)
portfolios_poor['Sharpe Ratio'] = (portfolios_poor['Returns']-rf) / portfolios_poor['Volatility']
portfolios_poor.head()
# Out:
#     Returns  Volatility  ATI weight  CIA weight  CLF weight  CRS weight  \
# 0  0.151022    0.384611    0.148580    0.140959    0.171026    0.241676
# 1  0.122519    0.371127    0.114085    0.314216    0.293432    0.186851
# 2  0.076486    0.327081    0.168990    0.374348    0.191276    0.033951
# 3  0.150346    0.395074    0.149324    0.256430    0.315925    0.213248
# 4  0.187257    0.420926    0.202130    0.096760    0.243047    0.236876
#
#    EVR weight  Sharpe Ratio
# 0    0.297759      0.353661
# 1    0.091416      0.289709
# 2    0.231436      0.187984
# 3    0.065074      0.342584
# 4    0.221186      0.409234

# %%
portfolios_good.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
# Out:
# <AxesSubplot:xlabel='Volatility', ylabel='Returns'>

# %%
portfolios_poor.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
# Out:
# <AxesSubplot:xlabel='Volatility', ylabel='Returns'>

# %% [markdown]
# # Minimun Variance

# %%
portfolios_good[portfolios_good['Volatility']==portfolios_good['Volatility'].min()]
# Out:
#         Returns  Volatility  APAM weight  PSK weight  TMV weight  TPL weight  \
# 67819  0.039143    0.108894     0.012513    0.741711    0.148851    0.005538
#
#        WPM weight  Sharpe Ratio
# 67819    0.091386      0.221714

# %%
portfolios_poor[portfolios_poor['Volatility']==portfolios_poor['Volatility'].min()]
# Out:
#          Returns  Volatility  ATI weight  CIA weight  CLF weight  CRS weight  \
# 657402 -0.014687    0.282236    0.034295    0.483101    0.002172    0.072573
#
#         EVR weight  Sharpe Ratio
# 657402     0.40786     -0.105186

# %%
min_var_port_good = portfolios_good.iloc[portfolios_good['Volatility'].idxmin()]
min_var_port_good
# Out:
# Returns         0.039143
# Volatility      0.108894
# APAM weight     0.012513
# PSK weight      0.741711
# TMV weight      0.148851
# TPL weight      0.005538
# WPM weight      0.091386
# Sharpe Ratio    0.221714
# Name: 67819, dtype: float64

# %%
min_var_port_poor = portfolios_poor.iloc[portfolios_poor['Volatility'].idxmin()]
min_var_port_poor
# Out:
# Returns        -0.014687
# Volatility      0.282236
# ATI weight      0.034295
# CIA weight      0.483101
# CLF weight      0.002172
# CRS weight      0.072573
# EVR weight      0.407860
# Sharpe Ratio   -0.105186
# Name: 657402, dtype: float64

# %%
portfolios_good.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
plt.scatter(min_var_port_good[1], min_var_port_good[0], color='r', s=50)

# %%
portfolios_poor.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
plt.scatter(min_var_port_poor[1], min_var_port_poor[0], color='r', s=50)

# %% [markdown]
# # Max Sharpe Ratio

# %% [markdown]
# $$Sharpe Ratio = \frac{E(R_i)-rf}{\sigma_i}$$

# %%
((portfolios_good['Returns']-rf)/portfolios_good['Volatility']).idxmax()
# Out:
# 674882

# %%
((portfolios_poor['Returns']-rf)/portfolios_poor['Volatility']).idxmax()
# Out:
# 281606

# %%
optimal_risky_port_good = portfolios_good.iloc[((portfolios_good['Returns']-rf)/portfolios_good['Volatility']).idxmax()]
optimal_risky_port_good
# Out:
# Returns         0.289666
# Volatility      0.324710
# APAM weight     0.038096
# PSK weight      0.001417
# TMV weight      0.018817
# TPL weight      0.359488
# WPM weight      0.582182
# Sharpe Ratio    0.845881
# Name: 674882, dtype: float64

# %%
optimal_risky_port_poor = portfolios_poor.iloc[((portfolios_poor['Returns']-rf)/portfolios_poor['Volatility']).idxmax()]
optimal_risky_port_poor
# Out:
# Returns         0.333168
# Volatility      0.597240
# ATI weight      0.202194
# CIA weight      0.006037
# CLF weight      0.758015
# CRS weight      0.003623
# EVR weight      0.030131
# Sharpe Ratio    0.532731
# Name: 281606, dtype: float64

# %%
portfolios_good.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
plt.scatter(min_var_port_good[1], min_var_port_good[0], color='r', s=50)
plt.scatter(optimal_risky_port_good[1], optimal_risky_port_good[0], color='r', s= 50)

# %%
portfolios_poor.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
plt.scatter(min_var_port_poor[1], min_var_port_poor[0], color='r', s=50)
plt.scatter(optimal_risky_port_poor[1], optimal_risky_port_poor[0], color='r', s= 50)

# %% [markdown]
# # Capital Allocation Line

# %% [markdown]
# $$E(R_P) = rf + \frac{E(R_i)-rf}{\sigma_i}\sigma_p$$

# %%
cal_x_good = []
cal_y_good = []

cal_x_poor = []
cal_y_poor = []

# %%
for er in np.linspace(rf, max(p_ret_good), n_cut):
    sd = (er - rf)/((optimal_risky_port_good[0]-rf)/optimal_risky_port_good[1])
    cal_x_good.append(sd)
    cal_y_good.append(er)
    
for er in np.linspace(rf, max(p_ret_poor), n_cut):
    sd = (er - rf)/((optimal_risky_port_poor[0]-rf)/optimal_risky_port_poor[1])
    cal_x_poor.append(sd)
    cal_y_poor.append(er)

# %%
data2_good = {'cal_y':cal_y_good, 'cal_x':cal_x_good}
cal_good = pd.DataFrame(data2_good)
cal_good.head()
# Out:
#       cal_y     cal_x
# 0  0.015000  0.000000
# 1  0.021886  0.008141
# 2  0.028772  0.016282
# 3  0.035658  0.024422
# 4  0.042545  0.032563

# %%
data2_poor = {'cal_y':cal_y_poor, 'cal_x':cal_x_poor}
cal_poor = pd.DataFrame(data2_poor)
cal_poor.head()
# Out:
#       cal_y     cal_x
# 0  0.015000  0.000000
# 1  0.021891  0.012935
# 2  0.028782  0.025870
# 3  0.035673  0.038805
# 4  0.042564  0.051740

# %%
portfolios_good.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
plt.scatter(min_var_port_good[1], min_var_port_good[0], color='r', s=50)
plt.scatter(optimal_risky_port_good[1], optimal_risky_port_good[0], color='r', s= 50)
plt.plot(cal_x_good, cal_y_good, color='r')

# %%
portfolios_poor.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
plt.scatter(min_var_port_poor[1], min_var_port_poor[0], color='r', s=50)
plt.scatter(optimal_risky_port_poor[1], optimal_risky_port_poor[0], color='r', s= 50)
plt.plot(cal_x_poor, cal_y_poor, color='r')

# %% [markdown]
# # Efficient Frontier

# %%
def get_ret_vol_sr(weights, month_ret):
    weights = np.array(weights)
    ret = np.sum(month_ret.mean() * weights) * 12
    vol = np.sqrt(np.dot(weights.T, np.dot(month_ret.cov()*12, weights)))
    sr = ret/vol
    return np.array([ret, vol, sr])

def check_sum(weights):
    #return 0 if sum of the weights is 1
    return np.sum(weights)-1

# %%
upper_bound_good = max(data_good["Returns"]) 
lower_bound_good = min(data_good["Returns"])
frontier_y_good = np.linspace(lower_bound_good - 0.05, upper_bound_good + 0.05, n_cut)

upper_bound_poor = max(data_poor["Returns"]) 
lower_bound_poor = min(data_poor["Returns"])
frontier_y_poor = np.linspace(lower_bound_poor - 0.05, upper_bound_poor + 0.05, n_cut)

# %%
def minimize_volatility(weights, month_ret):
    return get_ret_vol_sr(weights, month_ret)[1]

# %%
bounds_good = tuple( [ (0,1) for i in range(count_good) ] )
bounds_poor = tuple( [ (0,1) for i in range(count_poor) ] )

init_guess_good = [1/count_good] * count_good
init_guess_poor = [1/count_poor] * count_poor

# %%
frontier_x_good = []

for possible_return in frontier_y_good:
    cons = ({'type':'eq', 'fun':check_sum},
            {'type':'eq', 'fun': lambda w: get_ret_vol_sr(w, month_ret_good)[0] - possible_return})
    
    result = minimize(minimize_volatility,init_guess_good, month_ret_good, method='SLSQP', bounds=bounds_good, constraints=cons)
    frontier_x_good.append(result['fun'])
    
    
frontier_x_poor = []

for possible_return in frontier_y_poor:
    cons = ({'type':'eq', 'fun':check_sum},
            {'type':'eq', 'fun': lambda w: get_ret_vol_sr(w, month_ret_poor)[0] - possible_return})
    
    result = minimize(minimize_volatility,init_guess_poor, month_ret_poor, method='SLSQP', bounds=bounds_poor, constraints=cons)
    frontier_x_poor.append(result['fun'])

# %%
plt.figure(figsize=(12,8))
portfolios_good.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
plt.plot(frontier_x_good,frontier_y_good, 'r--', linewidth=2)

# plt.scatter(max_sr_vol, max_sr_ret,c='red', s=50) # red dot
# plt.scatter(min_var_vol, min_var_ret,c='red',marker='x', s=50) # red dot
# plt.scatter(max_sr_vol2, max_sr_ret2,c='purple', s=50) # red dot
# plt.scatter(min_var_vol2, min_var_ret2,c='purple',marker='x', s=50) # red dot

plt.scatter(std_good, mean_good,c='red',marker='.', s=50) # red dot
# plt.savefig('cover.png')
plt.show()

# %%
plt.figure(figsize=(12,8))
portfolios_poor.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
plt.plot(frontier_x_poor,frontier_y_poor, 'r--', linewidth=2)

# plt.scatter(max_sr_vol, max_sr_ret,c='red', s=50) # red dot
# plt.scatter(min_var_vol, min_var_ret,c='red',marker='x', s=50) # red dot
# plt.scatter(max_sr_vol2, max_sr_ret2,c='purple', s=50) # red dot
# plt.scatter(min_var_vol2, min_var_ret2,c='purple',marker='x', s=50) # red dot

plt.scatter(std_poor, mean_poor,c='red',marker='.', s=50) # red dot
# plt.savefig('cover.png')
plt.show()

# %% [markdown]
# # Optimal compelete portfolio

# %%
optimal_y_good = (optimal_risky_port_good[0] - rf) / (A*optimal_risky_port_good[1]**2)
optimal_y_good
# Out:
# 0.6512583756357371

# %%
optimal_u_good = rf + optimal_y_good * (optimal_risky_port_good[0] - rf) - 0.5*A*optimal_y_good**2*optimal_risky_port_good[1]**2
optimal_u_good
# Out:
# 0.10443934596499947

# %%
optimal_sigma_good = optimal_y_good * optimal_risky_port_good[1]
optimal_er_good = rf + optimal_y_good * (optimal_risky_port_good[0] - rf) 
print("optimal deviation = ", optimal_sigma_good, "\n", 
      "optimal expected return = ", optimal_er_good, sep = '')
# Out:
# optimal deviation = 0.2114702650078723
# optimal expected return = 0.19387869192999896

# %%
optimal_y_poor = (optimal_risky_port_poor[0] - rf) / (A*optimal_risky_port_poor[1]**2)
optimal_y_poor
# Out:
# 0.22299680093176186

# %%
optimal_u_poor = rf + optimal_y_poor * (optimal_risky_port_poor[0] - rf) - 0.5*A*optimal_y_poor**2*optimal_risky_port_poor[1]**2
optimal_u_poor
# Out:
# 0.05047525548020403

# %%
optimal_sigma_poor = optimal_y_poor * optimal_risky_port_poor[1]
optimal_er_poor = rf + optimal_y_poor * (optimal_risky_port_poor[0] - rf) 
print("optimal deviation = ", optimal_sigma_poor, "\n", 
      "optimal expected return = ", optimal_er_poor, sep = '')
# Out:
# optimal deviation = 0.1331826855867609
# optimal expected return = 0.08595051096040807

# %% [markdown]
# # Utility Function

# %%
max_sigma_good = max(portfolios_good["Volatility"])

indifference_sigma_good = np.linspace(0, max_sigma_good, n_cut)
indifference_return_good = optimal_u_good + 0.5 * A * np.square( indifference_sigma_good )


max_sigma_poor = max(portfolios_poor["Volatility"])
min_sigma_poor = min(portfolios_poor["Volatility"])

indifference_sigma_poor = np.linspace(0, max_sigma_poor, n_cut)
indifference_return_poor = optimal_u_poor + 0.5 * A * np.square( indifference_sigma_poor )

# %%
plt.figure(figsize=(12,8))
portfolios_good.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
plt.plot(frontier_x_good, frontier_y_good, "r--", linewidth=2)
plt.plot(cal_x_good, cal_y_good, "r", linewidth=2)
plt.plot(indifference_sigma_good,indifference_return_good, 'r--', linewidth=2)

plt.scatter(optimal_sigma_good, optimal_er_good,c='red',marker='.', s=100) # red dot

# %%
plt.figure(figsize=(12,8))
portfolios_poor.plot.scatter(x='Volatility', y='Returns', c="Sharpe Ratio", cmap='viridis', grid=True, figsize=figsize)
plt.plot(frontier_x_poor, frontier_y_poor, "r--", linewidth=2)
plt.plot(cal_x_poor, cal_y_poor, "r", linewidth=2)
plt.plot(indifference_sigma_poor,indifference_return_poor, 'r--', linewidth=2)

plt.scatter(optimal_sigma_poor, optimal_er_poor,c='red',marker='.', s=100) # red dot

# %% [markdown]
# # Summary Graph

# %%
# Mean-var frontiers
plt.plot(frontier_x_good,frontier_y_good, 'g', linewidth=2, label = "Mean-variance frontier(good)")
plt.plot(frontier_x_poor,frontier_y_poor, 'r', linewidth=2, label = "Mean-variance frontier(poor)")

# Cal
plt.plot(cal_x_good, cal_y_good, 'g--', linewidth=2, label = "Cal(good)")
plt.plot(cal_x_poor, cal_y_poor, 'r--', linewidth=2, label = "Cal(poor)")

# Indifference curve
plt.plot(indifference_sigma_good,indifference_return_good, 'greenyellow', linewidth=2, label = "Indifference curve(good)")
plt.plot(indifference_sigma_poor,indifference_return_poor, 'tomato', linewidth=2, label = "Indifference curve(poor)")

# Optimal risky portfolio
plt.scatter(optimal_risky_port_good[1], optimal_risky_port_good[0], c = 'g', marker='.', s=300, zorder=100, label = "Optimal risky portfolio(good)")
plt.scatter(optimal_risky_port_poor[1], optimal_risky_port_poor[0], c = 'r', marker='.', s=300, zorder=100, label = "Optimal risky portfolio(poor)")

# Optimal complete portfolio
plt.scatter(optimal_sigma_good, optimal_er_good, c = 'greenyellow', marker='.', s=300, zorder=100, label = "Optimal complete portfolio(good)")
plt.scatter(optimal_sigma_poor, optimal_er_poor, c = 'tomato', marker='.', s=300, zorder=100, label = "Optimal complete portfolio(poor)")

# legend
plt.legend(loc="lower right", fontsize = "xx-small")
